# %%
from tensorflow.keras.models import model_from_json

# Load architecture
with open('model_architecture.json', 'r') as f:
    model_json = f.read()
model = model_from_json(model_json)

# Load weights
model.load_weights('model_weights.weights.h5')

# (Optional) compile for inference/evaluation
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Inspect
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 8, 32)      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 4, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 2, 64)      │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1664)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       106,560 │
# ...

# %%
import hls4ml

# Create HLS configuration
config = hls4ml.utils.config_from_keras_model(model)

# Convert model
hls_model = hls4ml.converters.convert_from_keras_model(
    model,
    hls_config=config,
    output_dir='cnn_hls',
    backend='Vitis'      # or 'Vivado'
)

# Generate HLS project
hls_model.write()

# Synthesize with Vitis/Vivado
hls_model.build()

# Read synthesis report
hls4ml.report.read_vivado_report('cnn_hls')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 18
#      15 hls_model.write()
#      17 # Synthesize with Vitis/Vivado
# ---> 18 hls_model.build()
#      20 # Read synthesis report
#      21 hls4ml.report.read_vivado_report('cnn_hls')
#
# File c:\Users\garet\AppData\Local\Programs\Python\Python313\Lib\site-packages\hls4ml\model\graph.py:1010, in ModelGraph.build(self, **kwargs)
#    1006 if not os.path.exists(self.config.get_output_dir()):
#    1007     # Assume the project wasn't written before
#    1008     self.write()
# -> 1010 return self.config.backend.build(self, **kwargs)
#
# File c:\Users\garet\AppData\Local\Programs\Python\Python313\Lib\site-packages\hls4ml\backends\vitis\vitis_backend.py:159, in VitisBackend.build(self, model, reset, csim, synth, cosim, validation, export, vsynth, fifo_opt, log_to_stdout)
#     156     process.communicate()
# ...

# %%
# Use Vivado HLS to synthesize the model
# This might take several minutes
hls_model.build()

# Print out the report if you want
hls4ml.report.read_vivado_report('model_architecture.json')
