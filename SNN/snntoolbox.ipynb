# %%
# !pip install snntoolbox
# Out:
# ...
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import snntoolbox.bin.run

snntoolbox.bin.run.main(path_to_config_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import snntoolbox.bin.run
#       2
# ----> 3 snntoolbox.bin.run.main(path_to_config_file)
#
# NameError: name 'path_to_config_file' is not defined
